# %% [markdown]
# # Simulating sensor degradation filtering
#
# This builds on the solution found in [the notebook exploring different ways to solve the VI problem (via fixing the parametric form of the surrogate distribution)](./exploring_vi_solutions.ipynb).

# %% [markdown]
# ## Analyzing different $n$, $t$, $f$ combinations
# Setting up various combinations of data.

# %%
import notebook_modules.general_module as gm
import notebook_modules.vi_simulation_module as vsm
import numpy as np

"""
Define random past values
"""
mu = [
    np.array([0.75, 0.75]),
    np.array([0.55, 0.95]),
    np.array([0.95, 0.55])
]

sigma = [
    # np.array([[1, 0.1], [0.1, 1]]),
    np.array([[2, 0.1], [0.1, 1]]),
    np.array([[1, 0.1], [0.1, 2]])
]

curr_obs = [
    gm.Observation(18, 35), # observed mixed number of tile colors
    gm.Observation(6, 35), # observed mostly white tiles
    gm.Observation(33, 35) # observed mostly black tiles
]
past_f = [
    0.95, # strongly black tile majority
    0.55 # almost no majority
]

param_combo = gm.ParamCombo(mu, sigma, curr_obs, past_f)

# %% [markdown]
# Defining models

# %%
"""
Define models
"""
# Sensor degradation model and covariance (slow degradation)
A = np.asarray([[1-gm.ZERO_APPROX/1e3, 0],
                [0, 1-gm.ZERO_APPROX/1e3]])
R = np.asarray([[1, 0],
                [0, 1]])

# %% [markdown]
# Defining cost functions

# %%
from scipy import stats, integrate, optimize

# Define integration limits (i.e., support) for the expectation
limits = [gm.ZERO_APPROX, 1-gm.ZERO_APPROX]

# Cost function for the MAP estimate
def MAP_cost_function(x, joint_dist: gm.MultiVarJointDist):
    return -joint_dist.pdf(x)

# Warm started ELBO
def warm_start_neg_ELBO(C, mu, sigma, joint_dist: gm.MultiVarJointDist):
    """Warm started ELBO using the MAP estimates of the joint distribution
    """

    if C.size == 3:
        cov = gm.reconstruct_cov_mat(C)
        surrogate_dist = stats.multivariate_normal(mean=mu, cov=cov) # params has 3 elements
    elif C.size == 2: surrogate_dist = stats.multivariate_normal(mean=mu, cov=np.diag(C)) # params has 2 elements
    elif C.size == 1:
        sigma[1,0] = C*np.sqrt(sigma[0,0] * sigma[1,1])
        sigma[0,1] = sigma[1,0]
        surrogate_dist = stats.multivariate_normal(mean=mu, cov=sigma) # params has 3 elements
    else: raise

    surrogate_norm_const, _ = integrate.dblquad(
        lambda x, y: surrogate_dist.pdf(np.array([x, y])), *limits, *limits
    )

    ln_expectation, _ = integrate.dblquad(
        lambda x, y: surrogate_dist.pdf(np.array([x, y])) * 
                     (
                         np.log(joint_dist.pdf(np.array([x, y]))) -
                         np.log(surrogate_dist.pdf(np.array([x, y]))) +
                         np.log(surrogate_norm_const)
                     ), *limits, *limits
    )
    return -(ln_expectation)/surrogate_norm_const

# %% [markdown]
# Run experiments

# %%
sim_data = vsm.SimDataVI(param_combo, A, R)

support_step_size = 1e-3
support = np.arange(gm.ZERO_APPROX, 1-gm.ZERO_APPROX, support_step_size) # n points
x, y = np.meshgrid(support, support)
pos = np.vstack((x.flatten(), y.flatten())).T # (n*n) x 2 vector of coordinate points
xlab = r"$\theta_1$"
ylab = r"$\theta_2$"

# Function to check whether eigenvalues of the covariance matrix are positive
def pos_def_constraint(params):
    if params.size == 3: cov_matrix_part = gm.reconstruct_cov_mat(params) # 3 values
    else: cov_matrix_part = np.diag(params) # 2 values
    return (np.linalg.eigvals(cov_matrix_part) - np.array([1e-6, 1e-6])).ravel()

# Define positive definiteness constraint
pos_def_constraint_dict = {"type": "ineq", "fun": pos_def_constraint}

for i, pc in enumerate(sim_data.get_param_combo().get_params()):

    # joint dist: p(theta_t, n_t, f)
    joint_dist = gm.MultiVarJointDist(dim=2)

    # Unpack params
    past_est = gm.Estimate(*pc[0])
    curr_obs = gm.Observation(*pc[1])
    past_f = pc[2]

    print("past_est.x={0}\npast_est.covar={1}\ncurr_obs.n={2}\ncurr_obs.t={3}\npast_f={4}"
          .format(past_est.x.flatten(),
                  past_est.covar.flatten(),
                  curr_obs.n,
                  curr_obs.t,
                  past_f))

    # Execute prediction step
    predicted_est = gm.prediction_step(past_est, A, R) # index 0 is the past estimate

    # Update joint distribution parameters
    joint_dist.update_binom_params(curr_obs.n, past_f, curr_obs.t)
    joint_dist.update_norm_params(predicted_est.x, predicted_est.covar)
    joint_dist.compute_norm_const()


    """Optimize over mean value"""
    x0_map = predicted_est.x

    map_result = optimize.minimize(
        MAP_cost_function,
        x0_map,
        args=(joint_dist),
        method="SLSQP",
        bounds=[(gm.ZERO_APPROX,1-gm.ZERO_APPROX), (gm.ZERO_APPROX,1-gm.ZERO_APPROX)]
    )

    print("\n###### Optimization results ######\n")
    print(map_result)
    print("Estimated mean:\n", map_result.x)
    print("Cost", -map_result.fun)
    print("\n####################################\n")


    """Optimize over diagonal covariance values"""
    bnds_warm_start_a = [*[(gm.ZERO_APPROX, np.inf) for _ in range(2)]] # 2 variables: c_11, c_22

    # Define initial guess as predicted covariance
    x0_warm_start_a = [predicted_est.covar[0,0], predicted_est.covar[1,1]]

    warm_start_result_a = optimize.minimize(
        warm_start_neg_ELBO,
        x0_warm_start_a,
        args=(map_result.x, None, joint_dist),
        method="SLSQP",
        bounds=bnds_warm_start_a,
        constraints=pos_def_constraint_dict
    )

    print("\n###### Optimization result ######\n")
    print(warm_start_result_a)
    print("Estimated diagonal covariance matrix:\n", np.diag(warm_start_result_a.x))
    print("ELBO", -warm_start_result_a.fun)
    print("\n####################################\n")


    """Optimize over correlation value"""
    # Define positive definiteness constraint for correlation seach
    def pos_def_constraint_corr(corr):
        cov_matrix_part = np.diag(warm_start_result_a.x)
        cov_matrix_part[0,1] = corr[0]
        cov_matrix_part[1,0] = cov_matrix_part[0,1]
        return (np.linalg.eigvals(cov_matrix_part) - np.array([1e-6, 1e-6])).ravel()

    pos_def_constraint_corr_dict = {"type": "ineq", "fun": pos_def_constraint_corr}

    # Define bounds for the correlation search
    bnds_warm_start_b = [(-1, 1)] # 3 variables: c_11, c_22, correlation

    # Define initial guess
    x0_warm_start_b = [0.]

    warm_start_result_b = optimize.minimize(
        warm_start_neg_ELBO,
        x0_warm_start_b,
        args=(map_result.x, np.diag(warm_start_result_a.x), joint_dist),
        method="SLSQP",
        bounds=bnds_warm_start_b,
        constraints=pos_def_constraint_corr_dict,
    )

    print("\n###### Optimization result ######\n")
    print(warm_start_result_b)
    print("Estimated correlation:\n", warm_start_result_b.x)
    print("ELBO", -warm_start_result_b.fun)
    print("\n####################################\n")


    """Compute distribution"""
    # Surrogate distribution; normalized to support
    covar_final = np.diag(warm_start_result_a.x)
    covar_final[0,1] = warm_start_result_b.x*np.sqrt(covar_final[0,0] * covar_final[1,1])
    covar_final[1,0] = covar_final[0,1]
    surr_dist = gm.TruncatedBivariateNormal(mu=map_result.x, sigma=covar_final)
    surr_dist_norm_const = integrate.simpson(
        integrate.simpson(surr_dist.pdf(pos, False).reshape(x.shape), support, axis=1),
        support
    )
    surr_dist.set_norm_const(surr_dist_norm_const)

    # Store data
    sim_data.store_data_pair(
        pc,
        joint_dist,
        surr_dist,
        [map_result, warm_start_result_a, warm_start_result_b]
    )

# Pickle data
sim_data.save()
# Out:
# past_est.x=[0.75 0.75]
# past_est.covar=[2.  0.1 0.1 1. ]
# curr_obs.n=18
# curr_obs.t=35
# past_f=0.95
#
# ###### Optimization results ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -4.763154686533222
#        x: [ 5.288e-01  7.504e-01]
#      nit: 5
#      jac: [ 7.069e-05 -3.207e-05]
#     nfev: 19
#     njev: 5
# Estimated mean:
#  [0.52879946 0.75037592]
# Cost 4.763154686533222
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.02910966045425303
#        x: [ 7.167e-03  1.964e+00]
#      nit: 11
#      jac: [ 3.454e-03  6.486e-04]
#     nfev: 40
#     njev: 11
# Estimated diagonal covariance matrix:
#  [[0.0071668  0.        ]
#  [0.         1.96398016]]
# ELBO -0.02910966045425303
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.022151554094979303
#        x: [ 1.186e-01]
#      nit: 5
#      jac: [-5.280e-02]
#     nfev: 11
#     njev: 5
# Estimated correlation:
#  [0.11863171]
# ELBO -0.022151554094979303
#
# ####################################
#
# past_est.x=[0.75 0.75]
# past_est.covar=[2.  0.1 0.1 1. ]
# curr_obs.n=18
# curr_obs.t=35
# past_f=0.55
#
# ###### Optimization results ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -2.9819737324936373
#        x: [ 7.362e-01  7.568e-01]
#      nit: 3
#      jac: [ 3.556e-03 -1.088e-03]
#     nfev: 12
#     njev: 3
# Estimated mean:
#  [0.73616369 0.75676048]
# Cost 2.9819737324936373
#
# ####################################
# /home/khaiyichin/research/sensor_degradation_filter/.venv/lib/python3.8/site-packages/scipy/optimize/_optimize.py:353: RuntimeWarning: Values in x were outside bounds during a minimize step, clipping to bounds
#   warnings.warn("Values in x were outside bounds during a "
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.8143749228338284
#        x: [ 2.287e-02  3.147e-02]
#      nit: 44
#      jac: [-7.110e-03 -1.337e-03]
#     nfev: 172
#     njev: 43
# Estimated diagonal covariance matrix:
#  [[0.02286777 0.        ]
#  [0.         0.03147499]]
# ELBO -0.8143749228338284
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.7962331408955843
#        x: [ 2.683e-02]
#      nit: 4
#      jac: [-6.695e-01]
#     nfev: 8
#     njev: 4
# Estimated correlation:
#  [0.02682743]
# ELBO -0.7962331408955843
#
# ####################################
#
# past_est.x=[0.75 0.75]
# past_est.covar=[2.  0.1 0.1 1. ]
# curr_obs.n=6
# curr_obs.t=35
# past_f=0.95
#
# ###### Optimization results ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -4.863312316706792e-10
#        x: [ 7.500e-01  7.500e-01]
#      nit: 1
#      jac: [ 4.490e-08 -2.363e-09]
#     nfev: 3
#     njev: 1
# Estimated mean:
#  [0.74999925 0.74999925]
# Cost 4.863312316706792e-10
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 14.179221486586911
#        x: [ 1.707e+03  5.101e-02]
#      nit: 60
#      jac: [ 0.000e+00 -1.111e-02]
#     nfev: 196
#     njev: 58
# Estimated diagonal covariance matrix:
#  [[1.70711578e+03 0.00000000e+00]
#  [0.00000000e+00 5.10148424e-02]]
# ELBO -14.179221486586911
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 14.170632004267436
#        x: [ 3.571e-01]
#      nit: 7
#      jac: [-1.363e-04]
#     nfev: 16
#     njev: 7
# Estimated correlation:
#  [0.35705222]
# ELBO -14.170632004267436
#
# ####################################
#
# past_est.x=[0.75 0.75]
# past_est.covar=[2.  0.1 0.1 1. ]
# curr_obs.n=6
# curr_obs.t=35
# past_f=0.55
#
# ###### Optimization results ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -8.447819004890993
#        x: [ 3.021e-01  9.858e-01]
#      nit: 7
#      jac: [ 1.001e-04 -8.905e-05]
#     nfev: 25
#     njev: 7
# Estimated mean:
#  [0.30213143 0.98578939]
# Cost 8.447819004890993
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5588332231551267
#        x: [ 1.455e-02  3.143e-02]
#      nit: 17
#      jac: [ 2.273e-02  9.485e-03]
#     nfev: 66
#     njev: 17
# Estimated diagonal covariance matrix:
#  [[0.01454785 0.        ]
#  [0.         0.03143405]]
# ELBO -0.5588332231551267
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5433321461627894
#        x: [ 2.138e-02]
#      nit: 6
#      jac: [-7.169e-01]
#     nfev: 13
#     njev: 6
# Estimated correlation:
#  [0.02138345]
# ELBO -0.5433321461627894
#
# ####################################
#
# past_est.x=[0.75 0.75]
# past_est.covar=[2.  0.1 0.1 1. ]
# curr_obs.n=33
# curr_obs.t=35
# past_f=0.95
#
# ###### Optimization results ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -10.903636907073313
#        x: [ 9.792e-01  7.496e-01]
#      nit: 7
#      jac: [ 7.142e-02 -5.015e-03]
#     nfev: 25
#     njev: 7
# Estimated mean:
#  [0.979172  0.7496266]
# Cost 10.903636907073313
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.051451103563771285
#        x: [ 4.873e-03  2.185e+00]
#      nit: 9
#      jac: [ 4.299e-02 -2.288e-04]
#     nfev: 31
#     njev: 9
# Estimated diagonal covariance matrix:
#  [[0.00487325 0.        ]
#  [0.         2.18483558]]
# ELBO -0.051451103563771285
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.047205767835031665
#        x: [ 1.032e-01]
#      nit: 6
#      jac: [-4.027e-02]
#     nfev: 12
#     njev: 6
# Estimated correlation:
#  [0.10317502]
# ELBO -0.047205767835031665
#
# ####################################
#
# past_est.x=[0.75 0.75]
# past_est.covar=[2.  0.1 0.1 1. ]
# curr_obs.n=33
# curr_obs.t=35
# past_f=0.55
#
# ###### Optimization results ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -9.69734297940172e-06
#        x: [ 7.500e-01  7.500e-01]
#      nit: 1
#      jac: [-3.128e-04  2.559e-04]
#     nfev: 3
#     njev: 1
# Estimated mean:
#  [0.74999925 0.74999925]
# Cost 9.69734297940172e-06
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 7.704289708927807
#        x: [ 1.114e-02  1.836e+03]
#      nit: 32
#      jac: [ 9.978e-05  5.960e-08]
#     nfev: 114
#     njev: 32
# Estimated diagonal covariance matrix:
#  [[1.11370982e-02 0.00000000e+00]
#  [0.00000000e+00 1.83557101e+03]]
# ELBO -7.704289708927807
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 7.7031899416213205
#        x: [-1.726e-01]
#      nit: 5
#      jac: [ 3.664e-04]
#     nfev: 13
#     njev: 5
# Estimated correlation:
#  [-0.1726403]
# ELBO -7.7031899416213205
#
# ####################################
#
# past_est.x=[0.75 0.75]
# past_est.covar=[1.  0.1 0.1 2. ]
# curr_obs.n=18
# curr_obs.t=35
# past_f=0.95
#
# ###### Optimization results ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -4.713191885901963
#        x: [ 5.294e-01  7.564e-01]
#      nit: 5
#      jac: [-3.314e-05 -1.729e-06]
#     nfev: 19
#     njev: 5
# Estimated mean:
#  [0.52940666 0.75639902]
# Cost 4.713191885901963
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.030165520326209054
#        x: [ 7.161e-03  2.993e+00]
#      nit: 9
#      jac: [ 6.112e-02  3.006e-04]
#     nfev: 34
#     njev: 9
# Estimated diagonal covariance matrix:
#  [[0.00716087 0.        ]
#  [0.         2.9933053 ]]
# ELBO -0.030165520326209054
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.023019258277331395
#        x: [ 1.464e-01]
#      nit: 6
#      jac: [-4.239e-02]
#     nfev: 12
#     njev: 6
# Estimated correlation:
#  [0.14639685]
# ELBO -0.023019258277331395
#
# ####################################
#
# past_est.x=[0.75 0.75]
# past_est.covar=[1.  0.1 0.1 2. ]
# curr_obs.n=18
# curr_obs.t=35
# past_f=0.55
#
# ###### Optimization results ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -2.975512210243991
#        x: [ 7.399e-01  7.613e-01]
#      nit: 4
#      jac: [ 1.321e-03 -2.204e-03]
#     nfev: 14
#     njev: 4
# Estimated mean:
#  [0.73986561 0.76125848]
# Cost 2.975512210243991
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.8210374745786035
#        x: [ 2.304e-02  3.184e-02]
#      nit: 33
#      jac: [ 4.602e-03  1.737e-03]
#     nfev: 119
#     njev: 32
# Estimated diagonal covariance matrix:
#  [[0.02304267 0.        ]
#  [0.         0.03183514]]
# ELBO -0.8210374745786035
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.8028531921612625
#        x: [ 2.708e-02]
#      nit: 4
#      jac: [-6.649e-01]
#     nfev: 8
#     njev: 4
# Estimated correlation:
#  [0.02708347]
# ELBO -0.8028531921612625
#
# ####################################
#
# past_est.x=[0.75 0.75]
# past_est.covar=[1.  0.1 0.1 2. ]
# curr_obs.n=6
# curr_obs.t=35
# past_f=0.95
#
# ###### Optimization results ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -4.94358759215882e-10
#        x: [ 7.500e-01  7.500e-01]
#      nit: 1
#      jac: [ 4.564e-08 -2.402e-09]
#     nfev: 3
#     njev: 1
# Estimated mean:
#  [0.74999925 0.74999925]
# Cost 4.94358759215882e-10
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 14.172677492496307
#        x: [ 6.683e+02  5.154e-02]
#      nit: 36
#      jac: [-2.146e-06  1.344e-03]
#     nfev: 128
#     njev: 35
# Estimated diagonal covariance matrix:
#  [[6.68254646e+02 0.00000000e+00]
#  [0.00000000e+00 5.15400448e-02]]
# ELBO -14.172677492496307
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 14.156956341254643
#        x: [ 4.048e-01]
#      nit: 7
#      jac: [-1.637e-04]
#     nfev: 15
#     njev: 7
# Estimated correlation:
#  [0.40480672]
# ELBO -14.156956341254643
#
# ####################################
#
# past_est.x=[0.75 0.75]
# past_est.covar=[1.  0.1 0.1 2. ]
# curr_obs.n=6
# curr_obs.t=35
# past_f=0.55
#
# ###### Optimization results ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -8.5688852802277
#        x: [ 3.139e-01  9.990e-01]
#      nit: 6
#      jac: [-3.310e-02 -7.588e-01]
#     nfev: 22
#     njev: 6
# Estimated mean:
#  [0.31387907 0.999     ]
# Cost 8.5688852802277
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.6007343182127195
#        x: [ 1.490e-02  3.125e-02]
#      nit: 17
#      jac: [ 9.691e-03  5.693e-03]
#     nfev: 63
#     njev: 17
# Estimated diagonal covariance matrix:
#  [[0.01490382 0.        ]
#  [0.         0.03124826]]
# ELBO -0.6007343182127195
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.58399844300315
#        x: [ 2.158e-02]
#      nit: 6
#      jac: [-7.669e-01]
#     nfev: 13
#     njev: 6
# Estimated correlation:
#  [0.02157944]
# ELBO -0.58399844300315
#
# ####################################
#
# past_est.x=[0.75 0.75]
# past_est.covar=[1.  0.1 0.1 2. ]
# curr_obs.n=33
# curr_obs.t=35
# past_f=0.95
#
# ###### Optimization results ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -10.752132985581287
#        x: [ 9.788e-01  7.434e-01]
#      nit: 7
#      jac: [-7.201e-02  3.859e-03]
#     nfev: 24
#     njev: 7
# Estimated mean:
#  [0.97876707 0.74337809]
# Cost 10.752132985581287
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.05206790166271628
#        x: [ 4.865e-03  3.029e+00]
#      nit: 8
#      jac: [ 5.046e-03 -1.344e-04]
#     nfev: 31
#     njev: 8
# Estimated diagonal covariance matrix:
#  [[0.00486511 0.        ]
#  [0.         3.02917075]]
# ELBO -0.05206790166271628
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.04775958760710638
#        x: [ 1.214e-01]
#      nit: 7
#      jac: [-3.471e-02]
#     nfev: 15
#     njev: 7
# Estimated correlation:
#  [0.1213877]
# ELBO -0.04775958760710638
#
# ####################################
#
# past_est.x=[0.75 0.75]
# past_est.covar=[1.  0.1 0.1 2. ]
# curr_obs.n=33
# curr_obs.t=35
# past_f=0.55
#
# ###### Optimization results ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -9.396743468057081e-06
#        x: [ 7.500e-01  7.500e-01]
#      nit: 1
#      jac: [-3.031e-04  2.480e-04]
#     nfev: 3
#     njev: 1
# Estimated mean:
#  [0.74999925 0.74999925]
# Cost 9.396743468057081e-06
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 7.7244529957421975
#        x: [ 1.109e-02  2.504e+03]
#      nit: 33
#      jac: [-2.378e-01  5.960e-08]
#     nfev: 114
#     njev: 33
# Estimated diagonal covariance matrix:
#  [[1.10921225e-02 0.00000000e+00]
#  [0.00000000e+00 2.50387293e+03]]
# ELBO -7.7244529957421975
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 7.7236277105366895
#        x: [-1.565e-01]
#      nit: 8
#      jac: [ 9.477e-05]
#     nfev: 16
#     njev: 8
# Estimated correlation:
#  [-0.15646828]
# ELBO -7.7236277105366895
#
# ####################################
#
# past_est.x=[0.55 0.95]
# past_est.covar=[2.  0.1 0.1 1. ]
# curr_obs.n=18
# curr_obs.t=35
# past_f=0.95
#
# ###### Optimization results ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -4.925282617043598
#        x: [ 5.388e-01  9.500e-01]
#      nit: 4
#      jac: [ 6.580e-03 -3.321e-04]
#     nfev: 15
#     njev: 4
# Estimated mean:
#  [0.53876332 0.95002448]
# Cost 4.925282617043598
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.05372147228751351
#        x: [ 7.127e-03  1.108e+00]
#      nit: 19
#      jac: [ 4.317e-02 -4.098e-05]
#     nfev: 65
#     njev: 19
# Estimated diagonal covariance matrix:
#  [[0.00712655 0.        ]
#  [0.         1.10824005]]
# ELBO -0.05372147228751351
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.04098788543892045
#        x: [ 8.887e-02]
#      nit: 6
#      jac: [-1.322e-01]
#     nfev: 13
#     njev: 6
# Estimated correlation:
#  [0.08886502]
# ELBO -0.04098788543892045
#
# ####################################
#
# past_est.x=[0.55 0.95]
# past_est.covar=[2.  0.1 0.1 1. ]
# curr_obs.n=18
# curr_obs.t=35
# past_f=0.55
#
# ###### Optimization results ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -3.0201869048830283
#        x: [ 7.895e-01  8.245e-01]
#      nit: 8
#      jac: [-6.361e-03  6.068e-03]
#     nfev: 25
#     njev: 8
# Estimated mean:
#  [0.7894876  0.82449944]
# Cost 3.0201869048830283
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.885093634217284
#        x: [ 2.826e-02  3.670e-02]
#      nit: 30
#      jac: [ 2.465e-03  1.513e-03]
#     nfev: 107
#     njev: 29
# Estimated diagonal covariance matrix:
#  [[0.02825955 0.        ]
#  [0.         0.0366958 ]]
# ELBO -0.885093634217284
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.8651435794946286
#        x: [ 3.220e-02]
#      nit: 4
#      jac: [-6.175e-01]
#     nfev: 8
#     njev: 4
# Estimated correlation:
#  [0.0322016]
# ELBO -0.8651435794946286
#
# ####################################
#
# past_est.x=[0.55 0.95]
# past_est.covar=[2.  0.1 0.1 1. ]
# curr_obs.n=6
# curr_obs.t=35
# past_f=0.95
#
# ###### Optimization results ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -6.469443601949859
#        x: [ 1.784e-01  9.507e-01]
#      nit: 7
#      jac: [-4.245e-02  1.380e-03]
#     nfev: 25
#     njev: 7
# Estimated mean:
#  [0.1784132 0.9506518]
# Cost 6.469443601949859
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.055970732324905126
#        x: [ 4.158e-03  1.466e+00]
#      nit: 9
#      jac: [-6.827e-03 -4.817e-04]
#     nfev: 35
#     njev: 9
# Estimated diagonal covariance matrix:
#  [[0.00415842 0.        ]
#  [0.         1.46644796]]
# ELBO -0.055970732324905126
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.050959302542604536
#        x: [ 7.808e-02]
#      nit: 4
#      jac: [-5.856e-02]
#     nfev: 8
#     njev: 4
# Estimated correlation:
#  [0.07808241]
# ELBO -0.050959302542604536
#
# ####################################
#
# past_est.x=[0.55 0.95]
# past_est.covar=[2.  0.1 0.1 1. ]
# curr_obs.n=6
# curr_obs.t=35
# past_f=0.55
#
# ###### Optimization results ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -8.57925573058959
#        x: [ 3.119e-01  9.990e-01]
#      nit: 4
#      jac: [-1.526e-02 -3.066e-01]
#     nfev: 15
#     njev: 4
# Estimated mean:
#  [0.3119265 0.999    ]
# Cost 8.57925573058959
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.6010204166729355
#        x: [ 1.481e-02  3.114e-02]
#      nit: 20
#      jac: [-9.089e-03  2.479e-03]
#     nfev: 74
#     njev: 20
# Estimated diagonal covariance matrix:
#  [[0.01481241 0.        ]
#  [0.         0.03114332]]
# ELBO -0.6010204166729355
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5843659489063582
#        x: [ 2.148e-02]
#      nit: 6
#      jac: [-7.669e-01]
#     nfev: 13
#     njev: 6
# Estimated correlation:
#  [0.021477]
# ELBO -0.5843659489063582
#
# ####################################
#
# past_est.x=[0.55 0.95]
# past_est.covar=[2.  0.1 0.1 1. ]
# curr_obs.n=33
# curr_obs.t=35
# past_f=0.95
#
# ###### Optimization results ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -3.2680292556115047e-06
#        x: [ 5.500e-01  9.500e-01]
#      nit: 1
#      jac: [-1.821e-04  9.583e-06]
#     nfev: 3
#     njev: 1
# Estimated mean:
#  [0.54999945 0.94999905]
# Cost 3.2680292556115047e-06
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 12.877010203402245
#        x: [ 8.408e-03  2.433e+03]
#      nit: 32
#      jac: [-4.951e-02  0.000e+00]
#     nfev: 100
#     njev: 32
# Estimated diagonal covariance matrix:
#  [[8.40826995e-03 0.00000000e+00]
#  [0.00000000e+00 2.43293303e+03]]
# ELBO -12.877010203402245
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 12.865878386567472
#        x: [-3.297e-01]
#      nit: 6
#      jac: [ 1.296e-04]
#     nfev: 13
#     njev: 6
# Estimated correlation:
#  [-0.32968197]
# ELBO -12.865878386567472
#
# ####################################
#
# past_est.x=[0.55 0.95]
# past_est.covar=[2.  0.1 0.1 1. ]
# curr_obs.n=33
# curr_obs.t=35
# past_f=0.55
#
# ###### Optimization results ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -2.879603729513375e-12
#        x: [ 5.500e-01  9.500e-01]
#      nit: 1
#      jac: [-1.561e-10  1.277e-10]
#     nfev: 3
#     njev: 1
# Estimated mean:
#  [0.54999945 0.94999905]
# Cost 2.879603729513375e-12
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 13.564651021655049
#        x: [ 1.746e-02  2.758e+03]
#      nit: 37
#      jac: [ 3.683e-02 -1.192e-07]
#     nfev: 122
#     njev: 37
# Estimated diagonal covariance matrix:
#  [[1.74601524e-02 0.00000000e+00]
#  [0.00000000e+00 2.75780854e+03]]
# ELBO -13.564651021655049
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 13.557969932147778
#        x: [-2.795e-01]
#      nit: 7
#      jac: [ 1.730e-04]
#     nfev: 15
#     njev: 7
# Estimated correlation:
#  [-0.27951206]
# ELBO -13.557969932147778
#
# ####################################
#
# past_est.x=[0.55 0.95]
# past_est.covar=[1.  0.1 0.1 2. ]
# curr_obs.n=18
# curr_obs.t=35
# past_f=0.95
#
# ###### Optimization results ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -4.8187123721074085
#        x: [ 5.388e-01  9.499e-01]
#      nit: 3
#      jac: [ 8.549e-03 -1.101e-03]
#     nfev: 11
#     njev: 3
# Estimated mean:
#  [0.53877602 0.94991925]
# Cost 4.8187123721074085
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.05615707264830732
#        x: [ 7.113e-03  2.995e+00]
#      nit: 9
#      jac: [ 5.618e-02  7.818e-04]
#     nfev: 34
#     njev: 9
# Estimated diagonal covariance matrix:
#  [[0.00711319 0.        ]
#  [0.         2.99510814]]
# ELBO -0.05615707264830732
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.042612901123360095
#        x: [ 1.460e-01]
#      nit: 5
#      jac: [-8.300e-02]
#     nfev: 10
#     njev: 5
# Estimated correlation:
#  [0.14595162]
# ELBO -0.042612901123360095
#
# ####################################
#
# past_est.x=[0.55 0.95]
# past_est.covar=[1.  0.1 0.1 2. ]
# curr_obs.n=18
# curr_obs.t=35
# past_f=0.55
#
# ###### Optimization results ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -2.963903179310853
#        x: [ 7.209e-01  7.408e-01]
#      nit: 7
#      jac: [-3.617e-03  9.630e-04]
#     nfev: 23
#     njev: 7
# Estimated mean:
#  [0.72086413 0.74078338]
# Cost 2.963903179310853
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.8027763429208846
#        x: [ 2.202e-02  3.099e-02]
#      nit: 35
#      jac: [-1.917e-02 -1.521e-03]
#     nfev: 126
#     njev: 34
# Estimated diagonal covariance matrix:
#  [[0.02202171 0.        ]
#  [0.         0.03099258]]
# ELBO -0.8027763429208846
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.7845066986137252
#        x: [ 2.612e-02]
#      nit: 4
#      jac: [-6.916e-01]
#     nfev: 8
#     njev: 4
# Estimated correlation:
#  [0.02612394]
# ELBO -0.7845066986137252
#
# ####################################
#
# past_est.x=[0.55 0.95]
# past_est.covar=[1.  0.1 0.1 2. ]
# curr_obs.n=6
# curr_obs.t=35
# past_f=0.95
#
# ###### Optimization results ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -6.329313466744627
#        x: [ 1.792e-01  9.608e-01]
#      nit: 8
#      jac: [ 2.447e-02 -1.300e-03]
#     nfev: 26
#     njev: 8
# Estimated mean:
#  [0.17924192 0.96075371]
# Cost 6.329313466744627
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.05665235873150104
#        x: [ 4.197e-03  2.934e+00]
#      nit: 7
#      jac: [-1.575e-01  2.691e-04]
#     nfev: 29
#     njev: 7
# Estimated diagonal covariance matrix:
#  [[0.00419733 0.        ]
#  [0.         2.93387667]]
# ELBO -0.05665235873150104
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.05106698384617419
#        x: [ 1.110e-01]
#      nit: 6
#      jac: [-4.576e-02]
#     nfev: 12
#     njev: 6
# Estimated correlation:
#  [0.11095727]
# ELBO -0.05106698384617419
#
# ####################################
#
# past_est.x=[0.55 0.95]
# past_est.covar=[1.  0.1 0.1 2. ]
# curr_obs.n=6
# curr_obs.t=35
# past_f=0.55
#
# ###### Optimization results ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -8.60228701297501
#        x: [ 3.125e-01  9.990e-01]
#      nit: 4
#      jac: [-1.974e-02 -6.521e-01]
#     nfev: 15
#     njev: 4
# Estimated mean:
#  [0.31245277 0.999     ]
# Cost 8.60228701297501
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.6004098760840665
#        x: [ 1.482e-02  3.118e-02]
#      nit: 17
#      jac: [ 8.691e-03  4.654e-03]
#     nfev: 63
#     njev: 17
# Estimated diagonal covariance matrix:
#  [[0.0148201  0.        ]
#  [0.         0.03118075]]
# ELBO -0.6004098760840665
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5837444836646529
#        x: [ 2.150e-02]
#      nit: 6
#      jac: [-7.667e-01]
#     nfev: 13
#     njev: 6
# Estimated correlation:
#  [0.02149548]
# ELBO -0.5837444836646529
#
# ####################################
#
# past_est.x=[0.55 0.95]
# past_est.covar=[1.  0.1 0.1 2. ]
# curr_obs.n=33
# curr_obs.t=35
# past_f=0.95
#
# ###### Optimization results ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -3.2294064874626535e-06
#        x: [ 5.500e-01  9.500e-01]
#      nit: 1
#      jac: [-1.799e-04  9.470e-06]
#     nfev: 3
#     njev: 1
# Estimated mean:
#  [0.54999945 0.94999905]
# Cost 3.2294064874626535e-06
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 12.865888737699008
#        x: [ 8.403e-03  6.309e+02]
#      nit: 30
#      jac: [-4.168e-03  3.576e-07]
#     nfev: 107
#     njev: 30
# Estimated diagonal covariance matrix:
#  [[8.40333678e-03 0.00000000e+00]
#  [0.00000000e+00 6.30899746e+02]]
# ELBO -12.865888737699008
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 12.838846618128994
#        x: [-4.056e-01]
#      nit: 6
#      jac: [-1.909e-04]
#     nfev: 13
#     njev: 6
# Estimated correlation:
#  [-0.40561189]
# ELBO -12.838846618128994
#
# ####################################
#
# past_est.x=[0.55 0.95]
# past_est.covar=[1.  0.1 0.1 2. ]
# curr_obs.n=33
# curr_obs.t=35
# past_f=0.55
#
# ###### Optimization results ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -2.7464382568041474e-12
#        x: [ 5.500e-01  9.500e-01]
#      nit: 1
#      jac: [-1.489e-10  1.218e-10]
#     nfev: 3
#     njev: 1
# Estimated mean:
#  [0.54999945 0.94999905]
# Cost 2.7464382568041474e-12
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 13.589849606348817
#        x: [ 1.751e-02  1.711e+03]
#      nit: 31
#      jac: [ 2.386e-01  1.192e-07]
#     nfev: 111
#     njev: 31
# Estimated diagonal covariance matrix:
#  [[1.75133471e-02 0.00000000e+00]
#  [0.00000000e+00 1.71147353e+03]]
# ELBO -13.589849606348817
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 13.580354372534272
#        x: [-3.066e-01]
#      nit: 6
#      jac: [ 2.338e-04]
#     nfev: 13
#     njev: 6
# Estimated correlation:
#  [-0.30662781]
# ELBO -13.580354372534272
#
# ####################################
#
# past_est.x=[0.95 0.55]
# past_est.covar=[2.  0.1 0.1 1. ]
# curr_obs.n=18
# curr_obs.t=35
# past_f=0.95
#
# ###### Optimization results ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -3.0317438970064025e-09
#        x: [ 9.500e-01  5.500e-01]
#      nit: 1
#      jac: [ 5.968e-07 -3.141e-08]
#     nfev: 3
#     njev: 1
# Estimated mean:
#  [0.94999905 0.54999945]
# Cost 3.0317438970064025e-09
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 6.171513825971337
#        x: [ 3.061e-01  1.291e-01]
#      nit: 39
#      jac: [ 1.489e-04  1.348e-04]
#     nfev: 135
#     njev: 37
# Estimated diagonal covariance matrix:
#  [[0.30609162 0.        ]
#  [0.         0.12909602]]
# ELBO -6.171513825971337
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 6.103886181165195
#        x: [ 1.988e-01]
#      nit: 5
#      jac: [-3.206e-01]
#     nfev: 11
#     njev: 5
# Estimated correlation:
#  [0.1987839]
# ELBO -6.103886181165195
#
# ####################################
#
# past_est.x=[0.95 0.55]
# past_est.covar=[2.  0.1 0.1 1. ]
# curr_obs.n=18
# curr_obs.t=35
# past_f=0.55
#
# ###### Optimization results ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -2.952905574726592
#        x: [ 6.837e-01  6.902e-01]
#      nit: 6
#      jac: [-3.576e-07  0.000e+00]
#     nfev: 21
#     njev: 6
# Estimated mean:
#  [0.68373094 0.69018322]
# Cost 2.952905574726592
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.7692496215702952
#        x: [ 2.096e-02  2.974e-02]
#      nit: 28
#      jac: [-7.099e-04 -2.250e-04]
#     nfev: 102
#     njev: 27
# Estimated diagonal covariance matrix:
#  [[0.02095621 0.        ]
#  [0.         0.02974255]]
# ELBO -0.7692496215702952
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.749966676205176
#        x: [ 2.496e-02]
#      nit: 4
#      jac: [-7.624e-01]
#     nfev: 8
#     njev: 4
# Estimated correlation:
#  [0.02496486]
# ELBO -0.749966676205176
#
# ####################################
#
# past_est.x=[0.95 0.55]
# past_est.covar=[2.  0.1 0.1 1. ]
# curr_obs.n=6
# curr_obs.t=35
# past_f=0.95
#
# ###### Optimization results ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -9.378162514981472e-26
#        x: [ 9.500e-01  5.500e-01]
#      nit: 1
#      jac: [ 3.387e-23 -1.783e-24]
#     nfev: 3
#     njev: 1
# Estimated mean:
#  [0.94999905 0.54999945]
# Cost 9.378162514981472e-26
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 14.598899974808926
#        x: [ 4.679e+03  8.470e-02]
#      nit: 50
#      jac: [ 0.000e+00 -7.245e-03]
#     nfev: 160
#     njev: 49
# Estimated diagonal covariance matrix:
#  [[4.67931009e+03 0.00000000e+00]
#  [0.00000000e+00 8.47016002e-02]]
# ELBO -14.598899974808926
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 14.598291063210537
#        x: [ 2.048e-01]
#      nit: 6
#      jac: [-1.686e-04]
#     nfev: 14
#     njev: 6
# Estimated correlation:
#  [0.20483724]
# ELBO -14.598291063210537
#
# ####################################
#
# past_est.x=[0.95 0.55]
# past_est.covar=[2.  0.1 0.1 1. ]
# curr_obs.n=6
# curr_obs.t=35
# past_f=0.55
#
# ###### Optimization results ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -6.918938473363617e-10
#        x: [ 9.500e-01  5.500e-01]
#      nit: 1
#      jac: [ 3.698e-08 -3.026e-08]
#     nfev: 3
#     njev: 1
# Estimated mean:
#  [0.94999905 0.54999945]
# Cost 6.918938473363617e-10
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 7.814311762964246
#        x: [ 2.775e+03  2.087e-02]
#      nit: 33
#      jac: [ 1.192e-07  1.280e-01]
#     nfev: 116
#     njev: 33
# Estimated diagonal covariance matrix:
#  [[2.77497278e+03 0.00000000e+00]
#  [0.00000000e+00 2.08682757e-02]]
# ELBO -7.814311762964246
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 7.8113036589166365
#        x: [-2.320e-01]
#      nit: 7
#      jac: [ 2.777e-04]
#     nfev: 16
#     njev: 7
# Estimated correlation:
#  [-0.23198896]
# ELBO -7.8113036589166365
#
# ####################################
#
# past_est.x=[0.95 0.55]
# past_est.covar=[2.  0.1 0.1 1. ]
# curr_obs.n=33
# curr_obs.t=35
# past_f=0.95
#
# ###### Optimization results ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -10.74409370880169
#        x: [ 9.688e-01  5.500e-01]
#      nit: 5
#      jac: [-5.446e-02  2.812e-03]
#     nfev: 18
#     njev: 5
# Estimated mean:
#  [0.96877532 0.54995585]
# Cost 10.74409370880169
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.04956604483789328
#        x: [ 4.152e-03  2.029e+00]
#      nit: 9
#      jac: [ 7.109e-03  3.950e-04]
#     nfev: 32
#     njev: 9
# Estimated diagonal covariance matrix:
#  [[0.00415224 0.        ]
#  [0.         2.02881942]]
# ELBO -0.04956604483789328
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.045832055410597754
#        x: [ 9.177e-02]
#      nit: 6
#      jac: [-3.940e-02]
#     nfev: 12
#     njev: 6
# Estimated correlation:
#  [0.09177211]
# ELBO -0.045832055410597754
#
# ####################################
#
# past_est.x=[0.95 0.55]
# past_est.covar=[2.  0.1 0.1 1. ]
# curr_obs.n=33
# curr_obs.t=35
# past_f=0.55
#
# ###### Optimization results ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -31.13929697764661
#        x: [ 9.990e-01  1.274e-01]
#      nit: 6
#      jac: [-7.360e+00  2.127e-03]
#     nfev: 22
#     njev: 6
# Estimated mean:
#  [0.999      0.12739711]
# Cost 31.13929697764661
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.16281922950381425
#        x: [ 1.145e-02  9.857e-03]
#      nit: 17
#      jac: [-1.385e-02  3.475e-02]
#     nfev: 66
#     njev: 17
# Estimated diagonal covariance matrix:
#  [[0.01144793 0.        ]
#  [0.         0.00985722]]
# ELBO -0.16281922950381425
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.15906313215864512
#        x: [ 1.062e-02]
#      nit: 4
#      jac: [-3.496e-01]
#     nfev: 8
#     njev: 4
# Estimated correlation:
#  [0.01062184]
# ELBO -0.15906313215864512
#
# ####################################
#
# past_est.x=[0.95 0.55]
# past_est.covar=[1.  0.1 0.1 2. ]
# curr_obs.n=18
# curr_obs.t=35
# past_f=0.95
#
# ###### Optimization results ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -3.0602165150333183e-09
#        x: [ 9.500e-01  5.500e-01]
#      nit: 1
#      jac: [ 6.024e-07 -3.170e-08]
#     nfev: 3
#     njev: 1
# Estimated mean:
#  [0.94999905 0.54999945]
# Cost 3.0602165150333183e-09
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 6.172343606531776
#        x: [ 3.043e-01  1.311e-01]
#      nit: 34
#      jac: [ 3.494e-03  1.621e-03]
#     nfev: 119
#     njev: 33
# Estimated diagonal covariance matrix:
#  [[0.30426568 0.        ]
#  [0.         0.13111039]]
# ELBO -6.172343606531776
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 6.104527752323888
#        x: [ 1.997e-01]
#      nit: 5
#      jac: [-3.200e-01]
#     nfev: 11
#     njev: 5
# Estimated correlation:
#  [0.19973026]
# ELBO -6.104527752323888
#
# ####################################
#
# past_est.x=[0.95 0.55]
# past_est.covar=[1.  0.1 0.1 2. ]
# curr_obs.n=18
# curr_obs.t=35
# past_f=0.55
#
# ###### Optimization results ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -2.988179532930783
#        x: [ 7.600e-01  7.832e-01]
#      nit: 7
#      jac: [ 2.325e-06  0.000e+00]
#     nfev: 24
#     njev: 7
# Estimated mean:
#  [0.76001891 0.78319926]
# Cost 2.988179532930783
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.8435696853690617
#        x: [ 2.453e-02  3.318e-02]
#      nit: 28
#      jac: [-9.504e-03 -2.150e-02]
#     nfev: 102
#     njev: 28
# Estimated diagonal covariance matrix:
#  [[0.02453049 0.        ]
#  [0.         0.03318345]]
# ELBO -0.8435696853690617
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.8251295437528493
#        x: [ 2.853e-02]
#      nit: 4
#      jac: [-6.414e-01]
#     nfev: 8
#     njev: 4
# Estimated correlation:
#  [0.02852982]
# ELBO -0.8251295437528493
#
# ####################################
#
# past_est.x=[0.95 0.55]
# past_est.covar=[1.  0.1 0.1 2. ]
# curr_obs.n=6
# curr_obs.t=35
# past_f=0.95
#
# ###### Optimization results ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -9.795945907079452e-26
#        x: [ 9.500e-01  5.500e-01]
#      nit: 1
#      jac: [ 3.538e-23 -1.862e-24]
#     nfev: 3
#     njev: 1
# Estimated mean:
#  [0.94999905 0.54999945]
# Cost 9.795945907079452e-26
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 14.574718560074142
#        x: [ 3.033e+03  8.574e-02]
#      nit: 41
#      jac: [ 0.000e+00  5.303e-03]
#     nfev: 134
#     njev: 41
# Estimated diagonal covariance matrix:
#  [[3.03303321e+03 0.00000000e+00]
#  [0.00000000e+00 8.57433734e-02]]
# ELBO -14.574718560074142
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 14.573881798135458
#        x: [ 2.250e-01]
#      nit: 7
#      jac: [-3.524e-04]
#     nfev: 16
#     njev: 7
# Estimated correlation:
#  [0.22496373]
# ELBO -14.573881798135458
#
# ####################################
#
# past_est.x=[0.95 0.55]
# past_est.covar=[1.  0.1 0.1 2. ]
# curr_obs.n=6
# curr_obs.t=35
# past_f=0.55
#
# ###### Optimization results ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -7.222207748418857e-10
#        x: [ 9.500e-01  5.500e-01]
#      nit: 1
#      jac: [ 3.860e-08 -3.158e-08]
#     nfev: 3
#     njev: 1
# Estimated mean:
#  [0.94999905 0.54999945]
# Cost 7.222207748418857e-10
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 7.793515557222424
#        x: [ 2.824e+03  2.087e-02]
#      nit: 35
#      jac: [ 0.000e+00  1.011e-01]
#     nfev: 113
#     njev: 35
# Estimated diagonal covariance matrix:
#  [[2.82439805e+03 0.00000000e+00]
#  [0.00000000e+00 2.08707682e-02]]
# ELBO -7.793515557222424
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 7.790624881286601
#        x: [-2.286e-01]
#      nit: 7
#      jac: [ 1.797e-04]
#     nfev: 16
#     njev: 7
# Estimated correlation:
#  [-0.22859933]
# ELBO -7.790624881286601
#
# ####################################
#
# past_est.x=[0.95 0.55]
# past_est.covar=[1.  0.1 0.1 2. ]
# curr_obs.n=33
# curr_obs.t=35
# past_f=0.95
#
# ###### Optimization results ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -10.669938917397689
#        x: [ 9.688e-01  5.495e-01]
#      nit: 5
#      jac: [-8.769e-02  4.577e-03]
#     nfev: 19
#     njev: 5
# Estimated mean:
#  [0.96875247 0.54946054]
# Cost 10.669938917397689
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.04987061218792269
#        x: [ 4.154e-03  3.004e+00]
#      nit: 8
#      jac: [ 4.062e-02  1.805e-04]
#     nfev: 31
#     njev: 8
# Estimated diagonal covariance matrix:
#  [[0.00415391 0.        ]
#  [0.         3.00355798]]
# ELBO -0.04987061218792269
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.04611753082745943
#        x: [ 1.117e-01]
#      nit: 7
#      jac: [-3.232e-02]
#     nfev: 15
#     njev: 7
# Estimated correlation:
#  [0.11168585]
# ELBO -0.04611753082745943
#
# ####################################
#
# past_est.x=[0.95 0.55]
# past_est.covar=[1.  0.1 0.1 2. ]
# curr_obs.n=33
# curr_obs.t=35
# past_f=0.55
#
# ###### Optimization results ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -31.111738654511466
#        x: [ 9.990e-01  1.269e-01]
#      nit: 7
#      jac: [-4.420e+00  5.031e-05]
#     nfev: 26
#     njev: 7
# Estimated mean:
#  [0.999      0.12685084]
# Cost 31.111738654511466
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.16331809431741215
#        x: [ 1.148e-02  9.779e-03]
#      nit: 20
#      jac: [ 2.971e-02 -1.832e-02]
#     nfev: 76
#     njev: 20
# Estimated diagonal covariance matrix:
#  [[0.01147574 0.        ]
#  [0.         0.00977914]]
# ELBO -0.16331809431741215
#
# ####################################
#
#
# ###### Optimization result ######
#
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.15956936866501417
#        x: [ 1.059e-02]
#      nit: 4
#      jac: [-3.499e-01]
#     nfev: 8
#     njev: 4
# Estimated correlation:
#  [0.01059253]
# ELBO -0.15956936866501417
#
# ####################################
